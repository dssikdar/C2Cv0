# %%
library(Seurat)
library(SeuratDisk)
library(NMF)
library(ggalluvial)
library(ComplexHeatmap)
library(CellChat)
library(patchwork)
library(graphics)
library(Matrix)
library(circlize)
library(colorspace)
library(pracma)
library(glue)

options(stringsAsFactors = FALSE, repr.plot.width = 12, repr.plot.height = 9, repr.plot.res = 300)

source("../Scripts/A-Sender_Receiver_Chord.r")
# Out:
# Loading required package: SeuratObject
#
# Loading required package: sp
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following object is masked from ‘package:base’:
#
#     intersect
#
#
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat
#
# Loading required package: registry
#
# Loading required package: rngtools
#
# Loading required package: cluster
#
# NMF - BioConductor layer [OK] | Shared memory capabilities [NO: bigmemory] | Cores 2/2
#
#   To enable shared memory capabilities, try: install.extras('
# NMF
# ')
#
# Loading required package: ggplot2
#
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.15.4
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite either one:
# - Gu, Z. Complex Heatmap Visualization. iMeta 2022.
# - Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#     genomic data. Bioinformatics 2016.
#
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:NMF’:
#
#     algorithm, compare
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     normalize, path, union
#
#
# The following object is masked from ‘package:Seurat’:
#
#     components
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# ========================================
# circlize version 0.4.16
# CRAN page: https://cran.r-project.org/package=circlize
# Github page: https://github.com/jokergoo/circlize
# Documentation: https://jokergoo.github.io/circlize_book/book/
#
# If you use it in published research, please cite:
# Gu, Z. circlize implements and enhances circular visualization
#   in R. Bioinformatics 2014.
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(circlize))
# ========================================
#
#
#
# Attaching package: ‘circlize’
#
#
# The following object is masked from ‘package:igraph’:
#
#     degree
#
#
#
# Attaching package: ‘pracma’
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expm, lu, tril, triu

# %% [markdown]
# # Parameters

# %%
# for plotting figC, differential network
disease = "AD"
project = "AD_Paper"

type <- "truncatedMean"
trim <- 0.05

# %%
cellchat.CT <- readRDS(file = glue("/extra/zhanglab0/CommonData/AMP-AD/Obj-CellChat/subclass_cellchat_control.rds"))
cellchat.AD <- readRDS(file = glue("/extra/zhanglab0/CommonData/AMP-AD/Obj-CellChat/subclass_cellchat_alz.rds"))

# %%
cellchat.CT <- updateCellChat(cellchat.CT)
cellchat.AD <- updateCellChat(cellchat.AD)

# %%
object.list_ADvCON <- list(CON = cellchat.CT, AD = cellchat.AD)
cellchat_ADvCON <- mergeCellChat(object.list_ADvCON, add.names = names(object.list_ADvCON))
print(cellchat_ADvCON)
print(names(object.list_ADvCON))
# Out:
# Merge the following slots: 'data.signaling','net', 'netP','meta', 'idents', 'var.features' , 'DB', and 'LR'.
# An object of class CellChat created from a merged object with multiple datasets
#  704 signaling genes.
#  51171 cells.[1] "CON" "AD"

# %%
celltype_name = c('Astro', 'Endo', 'Oligo', 'OPC', 'VLMC', 'Micro/PVM', 
                  'Chandelier', 'Lamp5', 'Lamp5 Lhx6', 'Pax6', 'Pvalb', 'Sncg', 'Sst', 'Vip', 'Sst Chodl', 
                  'L2/3 IT', 'L4 IT', 'L5', 'L5/6 NP', 'L6 CT', 'L6 IT', 'L6 IT Car3', 'L6b')

measure = 'weight'

# %%
color.use = c(rainbow_hcl(7, c = 100), colorRampPalette(c("red", "orange"))(8), colorRampPalette(c("blue", "green"))(8))
color.use
# Out:
#  [1] "#FF7A9E" "#E69D00" "#8EBB00" "#00CC80" "#00CAE3" "#7CA7FF" "#FC77FA"
#  [8] "#FF0000" "#FF1700" "#FF2F00" "#FF4600" "#FF5E00" "#FF7500" "#FF8D00"
# [15] "#FFA500" "#0000FF" "#0024DA" "#0048B6" "#006D91" "#00916D" "#00B648"
# [22] "#00DA24" "#00FF00"

# %% [markdown]
# # Code

# %%
direction <- "to"

#Figure 4B
pathways.show      <- "WNT"
receiver <- c('Lamp5 Lhx6', 'Lamp5', 'L2/3 IT', 'L4 IT', 'L5', 'L5/6 NP', 'L6 CT', 'L6 IT', 'L6B', 'Sncg', 'Pvalb', 'Pax6')
sender <- c('Endo', 'L6 IT Car3')

#Figure 4C
#pathways.show      <- "CSF"
#receiver <- c('Micro/PVM')
#sender <- c('L6B')

#Figure 4D
#pathways.show      <- "TGFb"
#receiver <- c('Micro/PVM')
#sender <- c('Astro', 'Sncg')

#Figure 4E
#pathways.show      <- "CX3C"
#receiver <- c('Micro/PVM')
#sender <- c('Lamp5 Lhx6', 'Pvalb', 'L2/3 IT', 'L4 IT', 'L5', 'L5/6 NP', 'L6 CT', 'L6 IT', 'L6 IT Car3', 'L6B')

# %% [markdown]
# ## Cell Type

# %%
# get the matrix
obj1 <- object.list_ADvCON[[1]]@net[[measure]]              # CT
obj2 <- object.list_ADvCON[[2]]@net[[measure]]              # DIS
melt_1 <- reshape2::melt(obj1, value.name="count")
melt_2 <- reshape2::melt(obj2, value.name="count")
sum1 <- sum(melt_1$count)
sum2 <- sum(melt_2$count)

# balance
normalization_ADvCON = sum1 / sum2
# normalization = sum(object.list[[1]]@netP$prob) / sum(object.list[[2]]@netP$prob)
net.diff_ADvCON <- obj2 * (normalization_ADvCON) - obj1

# reorder the celltypes
net.diff_ADvCON <- net.diff_ADvCON[celltype_name, celltype_name]

net.diff_ADvCON[setdiff(celltype_name, sender), setdiff(celltype_name, receiver)] <- 0

# %% [raw]
# gg2 <- my_netVisual_aggregate2(net.diff_ADvCON, layout="chord", cell.order=celltype_name, signaling.name = pathways.show,
#                                color.use = color.use, vertex.label.cex = 2)
#
# if ("Micro/PVM" %in% sender) {sender[which(sender == "Micro/PVM")] <- "MicroPVM"}
# if ("Micro/PVM" %in% receiver) {receiver[which(receiver == "Micro/PVM")] <- "MicroPVM"}
#
# pdf(file = glue("chord-{direction}_{sender}+{receiver}-{pathways.show}-AD.pdf"), width = 15, height = 15)
# print(gg2)
# dev.off()

# %% [markdown]
# ## Pathway

# %%
# Don't change. Hard-coded
matrix.CT     <- cellchat.CT@netP$prob       # 14 x 14 x 946
matrix.AD     <- cellchat.AD@netP$prob       # 14 x 14 x 943
normalization <- sum(cellchat.CT@net$weight) / sum(cellchat.AD@net$weight)  # CT / AD, obtained from the 14x14 cell type matrix

pathways.show_weight.CT  <- matrix.CT[, , pathways.show]
pathways.show_weight.AD <- matrix.AD[, , pathways.show]
pathways.show_weight.differential <- pathways.show_weight.AD * normalization - pathways.show_weight.CT        # DIS - CON

# reorder the celltypes
pathways.show_weight.differential <- pathways.show_weight.differential[celltype_name, celltype_name]

pathways.show_weight.differential[setdiff(celltype_name, sender), setdiff(celltype_name, receiver)] <- 0

# %%
pathways.show_weight.differential
# Out:
#            Chandelier Lamp5      Lamp5 Lhx6   Pax6         Pvalb
# Chandelier 0           0.0000000  0.000000000  0.000000000  0.00000000
# Lamp5      0           0.0000000  0.000000000  0.000000000  0.00000000
# Lamp5 Lhx6 0           0.0000000  0.000000000  0.000000000  0.00000000
# Pax6       0           0.0000000  0.000000000  0.000000000  0.00000000
# Pvalb      0           0.0000000  0.000000000  0.000000000  0.00000000
# Sncg       0           0.0000000  0.000000000  0.000000000  0.00000000
# Sst        0           0.0000000  0.000000000  0.000000000  0.00000000
# Vip        0           0.0000000  0.000000000  0.000000000  0.00000000
# Sst Chodl  0           0.0000000  0.000000000  0.000000000  0.00000000
# L2/3 IT    0           0.0000000  0.000000000  0.000000000  0.00000000
# L4 IT      0           0.0000000  0.000000000  0.000000000  0.00000000
# L5         0           0.0000000  0.000000000  0.000000000  0.00000000
# L5/6 NP    0           0.0000000  0.000000000  0.000000000  0.00000000
# L6 CT      0           0.0000000  0.000000000  0.000000000  0.00000000
# L6 IT      0           0.0000000  0.000000000  0.000000000  0.00000000
# L6 IT Car3 0          -0.0232732 -0.012424501  0.006499925 -0.02127799
# L6b        0           0.0000000  0.000000000  0.000000000  0.00000000
# Astro      0           0.0000000  0.000000000  0.000000000  0.00000000
# Endo       0          -0.0177194 -0.009475316 -0.008966779 -0.01622676
# Oligo      0           0.0000000  0.000000000  0.000000000  0.00000000
# OPC        0           0.0000000  0.000000000  0.000000000  0.00000000
# VLMC       0           0.0000000  0.000000000  0.000000000  0.00000000
# Micro/PVM  0           0.0000000  0.000000000  0.000000000  0.00000000
#            Sncg       Sst Vip Sst Chodl L2/3 IT      ⋯ L6 CT       L6 IT
# Chandelier  0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Lamp5       0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Lamp5 Lhx6  0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Pax6        0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Pvalb       0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Sncg        0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Sst         0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Vip         0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Sst Chodl   0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# L2/3 IT     0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# L4 IT       0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# L5          0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# L5/6 NP     0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# L6 CT       0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# L6 IT       0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# L6 IT Car3 -0.0222292 0   0   0         -0.004411236 ⋯  0.01130680  0.007318486
# L6b         0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Astro       0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Endo       -0.0169312 0   0   0         -0.030387542 ⋯ -0.02705378 -0.019894961
# Oligo       0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# OPC         0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# VLMC        0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
# Micro/PVM   0.0000000 0   0   0          0.000000000 ⋯  0.00000000  0.000000000
#            L6 IT Car3   L6b          Astro Endo Oligo OPC VLMC Micro/PVM
# Chandelier  0.000000000  0.000000000 0     0    0     0   0    0
# Lamp5       0.000000000  0.000000000 0     0    0     0   0    0
# Lamp5 Lhx6  0.000000000  0.000000000 0     0    0     0   0    0
# Pax6        0.000000000  0.000000000 0     0    0     0   0    0
# Pvalb       0.000000000  0.000000000 0     0    0     0   0    0
# Sncg        0.000000000  0.000000000 0     0    0     0   0    0
# Sst         0.000000000  0.000000000 0     0    0     0   0    0
# Vip         0.000000000  0.000000000 0     0    0     0   0    0
# Sst Chodl   0.000000000  0.000000000 0     0    0     0   0    0
# L2/3 IT     0.000000000  0.000000000 0     0    0     0   0    0
# L4 IT       0.000000000  0.000000000 0     0    0     0   0    0
# L5          0.000000000  0.000000000 0     0    0     0   0    0
# L5/6 NP     0.000000000  0.000000000 0     0    0     0   0    0
# L6 CT       0.000000000  0.000000000 0     0    0     0   0    0
# L6 IT       0.000000000  0.000000000 0     0    0     0   0    0
# L6 IT Car3  0.002267459  0.001186844 0     0    0     0   0    0
# L6b         0.000000000  0.000000000 0     0    0     0   0    0
# Astro       0.000000000  0.000000000 0     0    0     0   0    0
# Endo       -0.025153972 -0.026050036 0     0    0     0   0    0
# Oligo       0.000000000  0.000000000 0     0    0     0   0    0
# OPC         0.000000000  0.000000000 0     0    0     0   0    0
# VLMC        0.000000000  0.000000000 0     0    0     0   0    0
# Micro/PVM   0.000000000  0.000000000 0     0    0     0   0    0

# %%
pathways.show
# Out:
# [1] "WNT"

# %%
gg2 <- my_netVisual_aggregate2(pathways.show_weight.differential, layout="chord", cell.order=celltype_name, color.use = color.use, 
                               signaling.name = pathways.show, vertex.label.cex = 2)

pdf(file = glue("Figure4B.pdf"), width = 20, height = 20) #pathways.show <- "WNT"
#pdf(file = glue("Figure4C.pdf"), width = 20, height = 20) #pathways.show <- "CSF"
#pdf(file = glue("Figure4D.pdf"), width = 20, height = 20) #pathways.show <- "TGBf"
#pdf(file = glue("Figure4E.pdf"), width = 20, height = 20) #pathways.show <- "CX3C"

print(gg2) 
dev.off()
# Out:
# png
#   2
# Plot with title “”
