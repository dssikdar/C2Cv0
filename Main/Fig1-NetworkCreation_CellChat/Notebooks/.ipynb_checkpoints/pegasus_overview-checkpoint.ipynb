# %%
# !pip install pegasuspy
# Out:
# Collecting pegasuspy
#   Obtaining dependency information for pegasuspy from https://files.pythonhosted.org/packages/58/6b/d6ea0aed8bbdd7cf5c4bb56df91fbc3caecf7d5738196e274684125ff871/pegasuspy-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pegasuspy-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting adjustText (from pegasuspy)
#   Obtaining dependency information for adjustText from https://files.pythonhosted.org/packages/86/68/2514c33e8afcdfb41eef05580e3c8ddb0f7d1fde7fbc84c9d3bb43286d53/adjustText-1.0.4-py3-none-any.whl.metadata
#   Downloading adjustText-1.0.4-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: anndata>=0.7.1 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (0.9.2)
# Collecting Cython (from pegasuspy)
#   Obtaining dependency information for Cython from https://files.pythonhosted.org/packages/f9/bd/e8a1d26d04c08a67bcc383f2ea5493a4e77f37a8770ead00a238b08ad729/Cython-3.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading Cython-3.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting docopt (from pegasuspy)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting demuxEM (from pegasuspy)
#   Obtaining dependency information for demuxEM from https://files.pythonhosted.org/packages/cb/54/f5899a715ea233388a3df1488dc0e431f30dff7f514fb539224663eeee27/demuxEM-0.1.7-py3-none-any.whl.metadata
#   Downloading demuxEM-0.1.7-py3-none-any.whl.metadata (2.2 kB)
# Collecting hnswlib (from pegasuspy)
#   Downloading hnswlib-0.8.0.tar.gz (36 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: psutil in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (5.9.5)
# Requirement already satisfied: threadpoolctl in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (3.2.0)
# Requirement already satisfied: joblib>=0.14 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (1.3.2)
# Collecting lightgbm>=2.2.1 (from pegasuspy)
#   Obtaining dependency information for lightgbm>=2.2.1 from https://files.pythonhosted.org/packages/ba/11/cb8b67f3cbdca05b59a032bb57963d4fe8c8d18c3870f30bed005b7f174d/lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl.metadata
#   Downloading lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Collecting loompy (from pegasuspy)
#   Downloading loompy-3.0.7.tar.gz (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 34.7 MB/s eta 0:00:0000:01:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: leidenalg in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (0.10.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (3.7.2)
# Requirement already satisfied: natsort in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (8.4.0)
# Requirement already satisfied: numba in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (0.57.1)
# Requirement already satisfied: numpy in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (1.24.4)
# Requirement already satisfied: pandas>=1.2.0 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (1.3.5)
# Collecting pegasusio>=0.9.0 (from pegasuspy)
#   Obtaining dependency information for pegasusio>=0.9.0 from https://files.pythonhosted.org/packages/6f/2e/fbee32b9cc4d720235c62e74d700d364e8d546dd47977ce314aeca22f572/pegasusio-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pegasusio-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting pybind11 (from pegasuspy)
#   Obtaining dependency information for pybind11 from https://files.pythonhosted.org/packages/06/55/9f73c32dda93fa4f539fafa268f9504e83c489f460c380371d94296126cd/pybind11-2.11.1-py3-none-any.whl.metadata
#   Using cached pybind11-2.11.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: scikit-learn>=0.23.2 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (1.3.0)
# Collecting scikit-misc (from pegasuspy)
#   Obtaining dependency information for scikit-misc from https://files.pythonhosted.org/packages/31/07/38b5ae87ba39f133860dd14ccfa26192fafb641ece632c36a535c5ae3736/scikit_misc-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scikit_misc-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: scipy in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (1.11.2)
# Collecting seaborn>=0.13.0 (from pegasuspy)
#   Obtaining dependency information for seaborn>=0.13.0 from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: setuptools in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (68.1.2)
# Requirement already satisfied: statsmodels in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (0.14.0)
# Requirement already satisfied: umap-learn>=0.5.2 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (0.5.3)
# Collecting wordcloud (from pegasuspy)
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/90/be/1a7a488f5edcfae6746ffb91e792a1795b6cc058364ea6888b3878d3476f/wordcloud-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading wordcloud-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting xlsxwriter (from pegasuspy)
#   Obtaining dependency information for xlsxwriter from https://files.pythonhosted.org/packages/a7/ea/53d1fe468e63e092cf16e2c18d16f50c29851242f9dd12d6a66e0d7f0d02/XlsxWriter-3.2.0-py3-none-any.whl.metadata
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: igraph in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pegasuspy) (0.10.6)
# Requirement already satisfied: h5py>=3 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from anndata>=0.7.1->pegasuspy) (3.9.0)
# Requirement already satisfied: packaging>=20 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from anndata>=0.7.1->pegasuspy) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from matplotlib>=2.0.0->pegasuspy) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from matplotlib>=2.0.0->pegasuspy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from matplotlib>=2.0.0->pegasuspy) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from matplotlib>=2.0.0->pegasuspy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from matplotlib>=2.0.0->pegasuspy) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from matplotlib>=2.0.0->pegasuspy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from matplotlib>=2.0.0->pegasuspy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from pandas>=1.2.0->pegasuspy) (2023.3)
# Collecting zarr (from pegasusio>=0.9.0->pegasuspy)
#   Obtaining dependency information for zarr from https://files.pythonhosted.org/packages/f1/69/ecaaa497d704c58621d0828bd1336d8040e09c94e822ca8d28410fbdeff2/zarr-2.17.0-py3-none-any.whl.metadata
#   Downloading zarr-2.17.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pynndescent>=0.5 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from umap-learn>=0.5.2->pegasuspy) (0.5.10)
# Requirement already satisfied: tqdm in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from umap-learn>=0.5.2->pegasuspy) (4.66.1)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from numba->pegasuspy) (0.40.1)
# Requirement already satisfied: texttable>=1.6.2 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from igraph->pegasuspy) (1.6.7)
# Requirement already satisfied: click in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from loompy->pegasuspy) (8.1.7)
# Collecting numpy-groupies (from loompy->pegasuspy)
#   Obtaining dependency information for numpy-groupies from https://files.pythonhosted.org/packages/e8/17/699b13d0355e625ff3114aa78b9d55ce8d948070ce6ed4be06e1a8b4996c/numpy_groupies-0.10.2-py3-none-any.whl.metadata
#   Downloading numpy_groupies-0.10.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: patsy>=0.5.2 in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from statsmodels->pegasuspy) (0.5.3)
# Requirement already satisfied: six in /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels->pegasuspy) (1.16.0)
# Collecting asciitree (from zarr->pegasusio>=0.9.0->pegasuspy)
#   Using cached asciitree-0.3.3.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting numcodecs>=0.10.0 (from zarr->pegasusio>=0.9.0->pegasuspy)
#   Obtaining dependency information for numcodecs>=0.10.0 from https://files.pythonhosted.org/packages/1e/b8/1040f299803eacc9c522fdc69a4dafc42ad0e8722bb48aa43d2310cf195b/numcodecs-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading numcodecs-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.8 kB)
# Collecting fasteners (from zarr->pegasusio>=0.9.0->pegasuspy)
#   Obtaining dependency information for fasteners from https://files.pythonhosted.org/packages/61/bf/fd60001b3abc5222d8eaa4a204cd8c0ae78e75adc688f33ce4bf25b7fafa/fasteners-0.19-py3-none-any.whl.metadata
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Downloading pegasuspy-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 34.4 MB/s eta 0:00:0000:01
# Downloading lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 36.4 MB/s eta 0:00:0000:01
# Downloading pegasusio-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 34.5 MB/s eta 0:00:0000:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 17.3 MB/s eta 0:00:00
# Downloading adjustText-1.0.4-py3-none-any.whl (11 kB)
# Downloading Cython-3.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 42.0 MB/s eta 0:00:0000:01m
# Downloading demuxEM-0.1.7-py3-none-any.whl (14 kB)
# Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Downloading scikit_misc-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 35.9 MB/s eta 0:00:0000:010:01
# Downloading wordcloud-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.1/511.1 kB 26.5 MB/s eta 0:00:00
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 11.8 MB/s eta 0:00:00
# Downloading numpy_groupies-0.10.2-py3-none-any.whl (39 kB)
# Downloading zarr-2.17.0-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 kB 13.0 MB/s eta 0:00:00
# Downloading numcodecs-0.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 38.1 MB/s eta 0:00:0000:0100:01
# Using cached fasteners-0.19-py3-none-any.whl (18 kB)
# Building wheels for collected packages: docopt, hnswlib, loompy, asciitree
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=6a5d9c2243d6d24edbfd072752c245040330ed159a88a56733b817519ee95fcb
#   Stored in directory: /home/dsikdar/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.8.0-cp310-cp310-linux_x86_64.whl size=193348 sha256=742ee891191f712c3f2c39ddd30cb0d779e04354eeca9efc7f86bea923e7a900
#   Stored in directory: /home/dsikdar/.cache/pip/wheels/af/a9/3e/3e5d59ee41664eb31a4e6de67d1846f86d16d93c45f277c4e7
#   Building wheel for loompy (setup.py) ... done
#   Created wheel for loompy: filename=loompy-3.0.7-py3-none-any.whl size=52018 sha256=7fa111ca68de2f41582f6aa83a7938584c8df62a3d3a142d5aaf95fc957aa71d
#   Stored in directory: /home/dsikdar/.cache/pip/wheels/2c/22/1f/792a4621bb631e538bf1c21feae9bbaa6b19fd6d6ab382d1fd
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5034 sha256=0dccfeac3fd42cfebf7c4d1cdc54776f15c8525e7a04145deac23db1c5534c82
#   Stored in directory: /home/dsikdar/.cache/pip/wheels/7f/4e/be/1171b40f43b918087657ec57cf3b81fa1a2e027d8755baa184
# Successfully built docopt hnswlib loompy asciitree
# Installing collected packages: docopt, asciitree, xlsxwriter, scikit-misc, pybind11, numpy-groupies, numcodecs, hnswlib, fasteners, Cython, zarr, loompy, lightgbm, wordcloud, seaborn, adjustText, pegasusio, demuxEM, pegasuspy
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed Cython-3.0.8 adjustText-1.0.4 asciitree-0.3.3 demuxEM-0.1.7 docopt-0.6.2 fasteners-0.19 hnswlib-0.8.0 lightgbm-4.3.0 loompy-3.0.7 numcodecs-0.12.1 numpy-groupies-0.10.2 pegasusio-0.9.0 pegasuspy-1.9.0 pybind11-2.11.1 scikit-misc-0.3.1 seaborn-0.13.2 wordcloud-1.9.3 xlsxwriter-3.2.0 zarr-2.17.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pegasus as pg
from pegasusio import UnimodalData, MultimodalData

pd.set_option('display.max_columns', None)
# Out:
# /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/dsikdar/.conda/envs/r_env_431/lib/python3.10/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
#data = pg.read_input(f'/gpfs/gibbs/pi/girgenti/JZhang/CL/C2C/AD_Paper/Data/AMP-AD_ROSMAP_annotated.h5ad')
data = pg.read_input('AMP-AD_ROSMAP_annotated.h5ad')

#meta = pd.read_csv('/gpfs/gibbs/pi/girgenti/JZhang/CL/C2C/AD_Paper/Data/meta_withDisorderInfo.csv', index_col=0)
meta = pd.read_csv('meta_withDisorderInfo.csv', index_col=0)
meta.set_index(keys="barcodekey", inplace=True)
meta = meta["Disorder"]
data.obs = data.obs.merge(meta, left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 #data = pg.read_input(f'/gpfs/gibbs/pi/girgenti/JZhang/CL/C2C/AD_Paper/Data/AMP-AD_ROSMAP_annotated.h5ad')
# ----> 2 data = pg.read_input('../../../extra/zhanglab0/CommonData/AMP-AD/AMP-AD_ROSMAP_annotated.h5ad')
#       4 #meta = pd.read_csv('/gpfs/gibbs/pi/girgenti/JZhang/CL/C2C/AD_Paper/Data/meta_withDisorderInfo.csv', index_col=0)
#       5 meta = pd.read_csv('/extra/zhanglab0/CommonData/AMP-AD/meta_withDisorderInfo.csv', index_col=0)
#
# File ~/.conda/envs/r_env_431/lib/python3.10/site-packages/pegasusio/decorators.py:12, in timer.<locals>.inner_decorator.<locals>.wrapper_timer(*args, **kwargs)
#       9 @functools.wraps(func)
#      10 def wrapper_timer(*args, **kwargs):
#      11 	start = time.perf_counter()
# ---> 12 	result = func(*args, **kwargs)
#      13 	end = time.perf_counter()
#      14 	message = f"Function '{func.__name__}' finished in {{:.{precision}f}}s.".format(end - start)
#
# File ~/.conda/envs/r_env_431/lib/python3.10/site-packages/pegasusio/readwrite.py:157, in read_input(input_file, file_type, mode, genome, modality, black_list, select_data, select_genome, select_modality, transpose)
#     155     data = zf.read_multimodal_data()
#     156 elif file_type == "h5ad":
# --> 157     data = MultimodalData(anndata.read_h5ad(input_file), genome = genome, modality = modality)
#     158 elif file_type == "loom":
#     159     data = load_loom_file(input_file, genome = genome, modality = modality)
#
# File ~/.conda/envs/r_env_431/lib/python3.10/site-packages/anndata/_io/h5ad.py:219, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     211         raise NotImplementedError(
#     212             "Currently only `X` and `raw/X` can be read as sparse."
#     213         )
#     215 rdasp = partial(
#     216     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     217 )
# --> 219 with h5py.File(filename, "r") as f:
#     221     def callback(func, elem_name: str, elem, iospec):
#     222         if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#
# File ~/.conda/envs/r_env_431/lib/python3.10/site-packages/h5py/_hl/files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File ~/.conda/envs/r_env_431/lib/python3.10/site-packages/h5py/_hl/files.py:231, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229     if swmr and swmr_support:
#     230         flags |= h5f.ACC_SWMR_READ
# --> 231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
#     233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '../../../extra/zhanglab0/CommonData/AMP-AD/AMP-AD_ROSMAP_annotated.h5ad', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
barcode_list = []
for ii,name in enumerate(data.obs_names):
    if data.obs.Disorder[ii] == 'cognitive impairment':
        barcode_list.append(False)
    else:
        barcode_list.append(True)
data_subset = data[barcode_list].copy()
data = MultimodalData(data_subset)
data
# Out:
# MultimodalData object with 1 UnimodalData: 'GRCh38-rna'
#     It currently binds to UnimodalData object GRCh38-rna
#
# UnimodalData object with n_obs x n_vars = 51171 x 32270
#     UID: GRCh38-rna; Genome: GRCh38; Modality: rna
#     It contains 2 matrices: 'X', 'raw.X'
#     It currently binds to matrix 'X' as X
#
#     obs: 'n_genes', 'n_counts', 'Channel', 'anno', 'subclass', 'azimuth', 'sampleID', 'individualID', 'Disorder'
#     var: 'featureid', 'n_cells', 'percent_cells'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_pca_regressed', 'X_pca_regressed_harmony', 'X_umap'(basis), 'pca_harmony_knn_distances'(knn), 'pca_harmony_knn_indices'(knn), 'pca_regressed_harmony_knn_distances'(knn), 'pca_regressed_harmony_knn_indices'(knn)
#     varm: 'de_res', 'means', 'partial_sum'
#     obsp: 'W_pca_harmony', 'W_pca_regressed_harmony'
#     uns: '_attr2type', 'genome', 'leiden_resolution', 'modality', 'ncells', 'norm_count', 'pca', 'pca_features', 'stdzn_max_value', 'stdzn_mean', 'stdzn_std', 'uns_dict', 'var_dict', 'uid'

# %%
data.obs['subclass'].replace(to_replace=['L5 ET', 'L5 IT'], value=["L5", "L5"], inplace=True)
data.obs.head()
# Out:
#                            n_genes  n_counts    Channel     anno subclass  \
# barcodekey
# D17-8754-TGGCTGGTCCTGCAGG    11079     75380  D17-8754-    L5 ET       L5
# D17-8754-CGCCAAGTCTGCTGCT    10354     62358  D17-8754-    L5 ET       L5
# D17-8754-ACATGGTCAGTATAAG    10703     61394  D17-8754-    L5 ET  L2/3 IT
# D17-8754-TCAGCTCTCGAGAGCA     9839     58428  D17-8754-    L5 ET    L6 IT
# D17-8754-CGTCTACCACAGGCCT    10428     56506  D17-8754-  L5 IT-5       L5
#
#                            azimuth  sampleID individualID             Disorder
# barcodekey
# D17-8754-TGGCTGGTCCTGCAGG    L5 IT  D17-8754        ROS45  Alzheimers/dementia
# D17-8754-CGCCAAGTCTGCTGCT    L5 IT  D17-8754        ROS45  Alzheimers/dementia
# D17-8754-ACATGGTCAGTATAAG  L2/3 IT  D17-8754        ROS45  Alzheimers/dementia
# D17-8754-TCAGCTCTCGAGAGCA    L6 IT  D17-8754        ROS45  Alzheimers/dementia
# D17-8754-CGTCTACCACAGGCCT    L5 IT  D17-8754        ROS45  Alzheimers/dementia

# %% [markdown]
# # Fig A,B: cell count and UMAP

# %%
data.obs.pivot_table(values="individualID", columns="Disorder", aggfunc="nunique")
# Out:
# Disorder      Alzheimers/dementia  cognitive impairment  control
# individualID                   23                    10       13

# %%
f = pg.scatter(data2, attrs=['subclass'], legend_loc=['on data'], panel_size=(2,2), return_fig=True)
plt.show()

f.savefig("plots-alz_inflam/UMAP.pdf", bbox_inches='tight')

# %% [markdown]
# # Fig C: marker gene

# %% [markdown]
# ## Individual

# %%
pg.de_analysis(data, cluster="subclass")
# Out:
# 2024-02-16 15:20:49,754 - pegasus.tools.diff_expr - INFO - CSR matrix is converted to CSC matrix. Time spent = 1.7453s.
# 2024-02-16 15:20:52,222 - pegasus.tools.diff_expr - INFO - MWU test and AUROC calculation are finished. Time spent = 2.4677s.
# 2024-02-16 15:20:52,468 - pegasus.tools.diff_expr - INFO - Sufficient statistics are collected. Time spent = 0.2463s.
# 2024-02-16 15:20:52,562 - pegasus.tools.diff_expr - INFO - Differential expression analysis is finished.
# 2024-02-16 15:20:52,563 - pegasus.tools.diff_expr - INFO - Function 'de_analysis' finished in 4.56s.

# %%
data.obs.subclass.unique()
# Out:
# ['L5', 'L2/3 IT', 'L6 IT', 'L6b', 'Pvalb', ..., 'Chandelier', 'Endo', 'L5/6 NP', 'Sst Chodl', 'Pax6']
# Length: 23
# Categories (23, object): ['Astro', 'Chandelier', 'Endo', 'L2/3 IT', ..., 'Sst', 'Sst Chodl', 'VLMC', 'Vip']

# %%
gene_list = ["AQP4", "GJA1", 
             "FLT1", "CLDN5", 
             "APBB1IP", "CX3CR1", 
             "MOBP", "MOG", 
             "OLIG1", "OLIG2", 
             "COLEC12", "EBF1", 
             "GAD1", "GAD2", 
             "SLC17A7", "SATB2"]

# %%
result = []
for group in [[x+"_CON", x+"_ALZ"] for x in ["Astro","Endo","Micro/PVM","Oligo","OPC","VLMC",
                             "Chandelier","Lamp5","Lamp5 Lhx6","Pax6","Pvalb","Sncg","Sst", "Sst Chodl","Vip",
                             "L2/3 IT","L4 IT","L5","L5/6 NP","L6 CT","L6 IT","L6 IT Car3","L6b"]]:
    result.append(group[0])
    result.append(group[1])

# %%
cluster_expr_CON
# Out:
#             Astro:log2Mean  Chandelier:log2Mean  Endo:log2Mean  \
# featurekey
# AQP4              5.107606             0.018561       0.214848
# GJA1              5.344326             0.018045       0.668854
# FLT1              0.019722             0.027327       7.113762
# CLDN5             0.022230             0.000000       8.267983
# APBB1IP           0.025736             0.065687       0.000000
# CX3CR1            0.004952             0.000000       0.000000
# MOBP              0.071930             0.016288       0.000000
# MOG               0.032972             0.017448       0.000000
# OLIG1             0.529334             0.068434       0.000000
# OLIG2             0.141791             0.000000       0.000000
# COLEC12           1.929365             0.086311       0.361009
# EBF1              0.036676             0.000000       3.230744
# GAD1              0.063494             2.466817       0.000000
# GAD2              0.016161             0.079420       0.124778
# SLC17A7           0.038962             0.307924       0.127109
# SATB2             0.154212             0.119320       0.252982
#
#             L2/3 IT:log2Mean  L4 IT:log2Mean  L5:log2Mean  L5/6 NP:log2Mean  \
# featurekey
# AQP4                0.219564        0.152526     0.160034          0.055188
# GJA1                0.005202        0.013178     0.013096          0.012910
# FLT1                0.029770        0.030349     0.037698          0.030504
# CLDN5               0.001231        0.001011     0.001979          0.000000
# APBB1IP             0.020717        0.037966     0.040057          0.093354
# CX3CR1              0.002346        0.001064     0.003172          0.008529
# MOBP                0.103665        0.134773     0.203940          0.315657
# MOG                 0.006370        0.011783     0.029650          0.025306
# OLIG1               0.007111        0.023481     0.041437          0.070178
# OLIG2               0.004751        0.011505     0.017073          0.038492
# COLEC12             0.071662        0.068296     0.060065          0.041576
# EBF1                0.010942        0.012983     0.021269          0.017506
# GAD1                0.013880        0.105518     0.121199          0.143478
# GAD2                0.015096        0.065312     0.111318          0.057054
# SLC17A7             4.694847        4.717628     5.222878          3.852758
# SATB2               4.079909        4.357694     3.786176          3.982055
#
#             L6 CT:log2Mean  L6 IT:log2Mean  L6 IT Car3:log2Mean  L6b:log2Mean  \
# featurekey
# AQP4              0.048872        0.272894             0.115805      0.134217
# GJA1              0.000000        0.025093             0.022420      0.044472
# FLT1              0.013225        0.033805             0.048771      0.038203
# CLDN5             0.005244        0.000729             0.000000      0.081876
# APBB1IP           0.027781        0.032043             0.022779      0.046492
# CX3CR1            0.000000        0.003414             0.000000      0.004906
# MOBP              0.096971        0.200180             0.165093      0.134327
# MOG               0.014351        0.022056             0.031244      0.027128
# OLIG1             0.039952        0.023357             0.032081      0.052737
# OLIG2             0.024871        0.018124             0.045465      0.013178
# COLEC12           0.026325        0.079125             0.115482      0.036282
# EBF1              0.013985        0.025941             0.017759      0.046266
# GAD1              0.104479        0.035902             0.075927      0.119450
# GAD2              0.066716        0.025610             0.034183      0.126249
# SLC17A7           4.542770        5.649103             5.448990      5.239626
# SATB2             2.603690        4.342196             5.658921      4.638515
#
#             Lamp5:log2Mean  Lamp5 Lhx6:log2Mean  Micro/PVM:log2Mean  \
# featurekey
# AQP4              0.014802             0.159017            0.044811
# GJA1              0.000000             0.000000            0.043539
# FLT1              0.029052             0.023331            0.225795
# CLDN5             0.018884             0.000000            0.000000
# APBB1IP           0.086505             0.107633            5.724475
# CX3CR1            0.006259             0.000000            2.183509
# MOBP              0.115769             0.092853            0.065947
# MOG               0.050342             0.048170            0.027564
# OLIG1             0.040428             0.018966            0.047078
# OLIG2             0.013170             0.008147            0.018126
# COLEC12           0.033798             0.061188            0.322217
# EBF1              0.022661             0.036424            0.045582
# GAD1              3.444886             3.230691            0.016789
# GAD2              5.083241             5.565710            0.006727
# SLC17A7           0.321496             0.436462            0.019088
# SATB2             0.095131             0.111125            0.087147
#
#             OPC:log2Mean  Oligo:log2Mean  Pax6:log2Mean  Pvalb:log2Mean  \
# featurekey
# AQP4            0.098787        0.005427       0.069847        0.018234
# GJA1            0.038417        0.006986       0.022436        0.020044
# FLT1            0.029086        0.013444       0.088358        0.122537
# CLDN5           0.000000        0.000898       0.000000        0.001020
# APBB1IP         0.050976        0.013072       0.024843        0.153575
# CX3CR1          0.013983        0.002329       0.000000        0.004043
# MOBP            0.027112        4.613994       0.024610        0.086190
# MOG             0.165935        2.731761       0.119055        0.028605
# OLIG1           4.914653        2.149786       0.054587        0.074289
# OLIG2           3.323763        0.893650       0.032914        0.012305
# COLEC12         0.080912        0.134388       0.088909        0.051730
# EBF1            0.048677        0.004806       0.048033        0.024547
# GAD1            1.774795        0.009060       3.746380        3.782350
# GAD2            0.038076        0.008155       3.200957        3.971198
# SLC17A7         0.047393        0.008285       0.513778        0.426514
# SATB2           0.057953        0.061143       0.157257        0.120361
#
#             Sncg:log2Mean  Sst:log2Mean  Sst Chodl:log2Mean  VLMC:log2Mean  \
# featurekey
# AQP4             0.040937      0.011840            0.000000       0.072322
# GJA1             0.000000      0.006375            0.261544       0.992577
# FLT1             0.022705      0.112501            0.000000       0.666089
# CLDN5            0.000000      0.000000            0.000000       0.644394
# APBB1IP          0.024082      0.015276            0.000000       0.043177
# CX3CR1           0.012299      0.000000            0.000000       0.096781
# MOBP             0.028134      0.065634            0.814053       0.086639
# MOG              0.030333      0.009326            0.592835       0.037192
# OLIG1            0.038752      0.038345            0.265748       0.037192
# OLIG2            0.013832      0.004210            0.235891       0.000000
# COLEC12          0.113131      0.011098            0.710244       3.863853
# EBF1             0.030940      0.010751            0.000000       3.846265
# GAD1             2.535565      3.066995            2.366292       0.049001
# GAD2             2.924790      2.659816            2.503723       0.042747
# SLC17A7          0.276795      0.329644            0.497435       0.033327
# SATB2            0.106813      0.093818            0.000000       0.161763
#
#             Vip:log2Mean
# featurekey
# AQP4            0.038985
# GJA1            0.013516
# FLT1            0.206634
# CLDN5           0.000000
# APBB1IP         0.022442
# CX3CR1          0.005599
# MOBP            0.029164
# MOG             0.018005
# OLIG1           0.058404
# OLIG2           0.010510
# COLEC12         0.071278
# EBF1            0.014190
# GAD1            3.104446
# GAD2            1.635644
# SLC17A7         0.241961
# SATB2           0.088325

# %%
cluster_expr = pg.search_genes(data, gene_list=gene_list, measure='log2Mean')
cluster_expr.columns = cluster_expr.columns.str.replace(r":log2Mean", "")
cluster_expr = cluster_expr[["Astro","Endo","Micro/PVM","Oligo","OPC","VLMC",
                             "Chandelier","Lamp5","Lamp5 Lhx6","Pax6","Pvalb","Sncg","Sst", "Sst Chodl","Vip",
                             "L2/3 IT","L4 IT","L5","L5/6 NP","L6 CT","L6 IT","L6 IT Car3","L6b"]]

# # cluster_expr_DIS = pg.search_genes(data_DIS, gene_list=gene_list, measure='log2Mean')
# # cluster_expr_DIS.columns = cluster_expr_DIS.columns.str.replace(r":log2Mean", "")
# # cluster_expr_DIS = cluster_expr_DIS[["Astro","Endo","Micro/PVM","Oligo","OPC","VLMC",
# #                              "Chandelier","Lamp5","Lamp5 Lhx6","Pax6","Pvalb","Sncg","Sst", "Sst Chodl","Vip",
# #                              "L2/3 IT","L4 IT","L5","L5/6 NP","L6 CT","L6 IT","L6 IT Car3","L6b"]]

# cluster_expr = cluster_expr_CON.merge(cluster_expr_DIS, left_index=True, right_index=True)
# cluster_expr.columns = cluster_expr.columns.str.replace(r"_x", "_CON")
# cluster_expr.columns = cluster_expr.columns.str.replace(r"_y", "_ALZ")
# cluster_expr = cluster_expr[result]

cluster_expr
# Out:
#                Astro      Endo  Micro/PVM     Oligo       OPC      VLMC  \
# featurekey
# AQP4        5.107606  0.214848   0.044811  0.005427  0.098787  0.072322
# GJA1        5.344326  0.668854   0.043539  0.006986  0.038417  0.992577
# FLT1        0.019722  7.113762   0.225795  0.013444  0.029086  0.666089
# CLDN5       0.022230  8.267983   0.000000  0.000898  0.000000  0.644394
# APBB1IP     0.025736  0.000000   5.724475  0.013072  0.050976  0.043177
# CX3CR1      0.004952  0.000000   2.183509  0.002329  0.013983  0.096781
# MOBP        0.071930  0.000000   0.065947  4.613994  0.027112  0.086639
# MOG         0.032972  0.000000   0.027564  2.731761  0.165935  0.037192
# OLIG1       0.529334  0.000000   0.047078  2.149786  4.914653  0.037192
# OLIG2       0.141791  0.000000   0.018126  0.893650  3.323763  0.000000
# COLEC12     1.929365  0.361009   0.322217  0.134388  0.080912  3.863853
# EBF1        0.036676  3.230744   0.045582  0.004806  0.048677  3.846265
# GAD1        0.063494  0.000000   0.016789  0.009060  1.774795  0.049001
# GAD2        0.016161  0.124778   0.006727  0.008155  0.038076  0.042747
# SLC17A7     0.038962  0.127109   0.019088  0.008285  0.047393  0.033327
# SATB2       0.154212  0.252982   0.087147  0.061143  0.057953  0.161763
#
#             Chandelier     Lamp5  Lamp5 Lhx6      Pax6     Pvalb      Sncg  \
# featurekey
# AQP4          0.018561  0.014802    0.159017  0.069847  0.018234  0.040937
# GJA1          0.018045  0.000000    0.000000  0.022436  0.020044  0.000000
# FLT1          0.027327  0.029052    0.023331  0.088358  0.122537  0.022705
# CLDN5         0.000000  0.018884    0.000000  0.000000  0.001020  0.000000
# APBB1IP       0.065687  0.086505    0.107633  0.024843  0.153575  0.024082
# CX3CR1        0.000000  0.006259    0.000000  0.000000  0.004043  0.012299
# MOBP          0.016288  0.115769    0.092853  0.024610  0.086190  0.028134
# MOG           0.017448  0.050342    0.048170  0.119055  0.028605  0.030333
# OLIG1         0.068434  0.040428    0.018966  0.054587  0.074289  0.038752
# OLIG2         0.000000  0.013170    0.008147  0.032914  0.012305  0.013832
# COLEC12       0.086311  0.033798    0.061188  0.088909  0.051730  0.113131
# EBF1          0.000000  0.022661    0.036424  0.048033  0.024547  0.030940
# GAD1          2.466817  3.444886    3.230691  3.746380  3.782350  2.535565
# GAD2          0.079420  5.083241    5.565710  3.200957  3.971198  2.924790
# SLC17A7       0.307924  0.321496    0.436462  0.513778  0.426514  0.276795
# SATB2         0.119320  0.095131    0.111125  0.157257  0.120361  0.106813
#
#                  Sst  Sst Chodl       Vip   L2/3 IT     L4 IT        L5  \
# featurekey
# AQP4        0.011840   0.000000  0.038985  0.219564  0.152526  0.160034
# GJA1        0.006375   0.261544  0.013516  0.005202  0.013178  0.013096
# FLT1        0.112501   0.000000  0.206634  0.029770  0.030349  0.037698
# CLDN5       0.000000   0.000000  0.000000  0.001231  0.001011  0.001979
# APBB1IP     0.015276   0.000000  0.022442  0.020717  0.037966  0.040057
# CX3CR1      0.000000   0.000000  0.005599  0.002346  0.001064  0.003172
# MOBP        0.065634   0.814053  0.029164  0.103665  0.134773  0.203940
# MOG         0.009326   0.592835  0.018005  0.006370  0.011783  0.029650
# OLIG1       0.038345   0.265748  0.058404  0.007111  0.023481  0.041437
# OLIG2       0.004210   0.235891  0.010510  0.004751  0.011505  0.017073
# COLEC12     0.011098   0.710244  0.071278  0.071662  0.068296  0.060065
# EBF1        0.010751   0.000000  0.014190  0.010942  0.012983  0.021269
# GAD1        3.066995   2.366292  3.104446  0.013880  0.105518  0.121199
# GAD2        2.659816   2.503723  1.635644  0.015096  0.065312  0.111318
# SLC17A7     0.329644   0.497435  0.241961  4.694847  4.717628  5.222878
# SATB2       0.093818   0.000000  0.088325  4.079909  4.357694  3.786176
#
#              L5/6 NP     L6 CT     L6 IT  L6 IT Car3       L6b
# featurekey
# AQP4        0.055188  0.048872  0.272894    0.115805  0.134217
# GJA1        0.012910  0.000000  0.025093    0.022420  0.044472
# FLT1        0.030504  0.013225  0.033805    0.048771  0.038203
# CLDN5       0.000000  0.005244  0.000729    0.000000  0.081876
# APBB1IP     0.093354  0.027781  0.032043    0.022779  0.046492
# CX3CR1      0.008529  0.000000  0.003414    0.000000  0.004906
# MOBP        0.315657  0.096971  0.200180    0.165093  0.134327
# MOG         0.025306  0.014351  0.022056    0.031244  0.027128
# OLIG1       0.070178  0.039952  0.023357    0.032081  0.052737
# OLIG2       0.038492  0.024871  0.018124    0.045465  0.013178
# COLEC12     0.041576  0.026325  0.079125    0.115482  0.036282
# EBF1        0.017506  0.013985  0.025941    0.017759  0.046266
# GAD1        0.143478  0.104479  0.035902    0.075927  0.119450
# GAD2        0.057054  0.066716  0.025610    0.034183  0.126249
# SLC17A7     3.852758  4.542770  5.649103    5.448990  5.239626
# SATB2       3.982055  2.603690  4.342196    5.658921  4.638515

# %%
cluster_expr.to_csv("subclass_markerExpr.csv", sep=",")

# %% [markdown]
# ## Separated

# %%
data_CON = data[data.obs["Disorder"] == "control"].copy()
data_DIS = data[data.obs["Disorder"] == "Alzheimers/dementia"].copy()

# %%
pg.de_analysis(data_CON, cluster="subclass")
pg.de_analysis(data_DIS, cluster="subclass")
# Out:
# 2024-02-16 15:19:06,985 - pegasus.tools.diff_expr - INFO - CSR matrix is converted to CSC matrix. Time spent = 0.7199s.
# 2024-02-16 15:19:25,805 - pegasus.tools.diff_expr - INFO - MWU test and AUROC calculation are finished. Time spent = 18.8201s.
# 2024-02-16 15:19:25,930 - pegasus.tools.diff_expr - INFO - Sufficient statistics are collected. Time spent = 0.1246s.
# 2024-02-16 15:19:26,027 - pegasus.tools.diff_expr - INFO - Differential expression analysis is finished.
# 2024-02-16 15:19:26,027 - pegasus.tools.diff_expr - INFO - Function 'de_analysis' finished in 19.78s.
# 2024-02-16 15:19:27,069 - pegasus.tools.diff_expr - INFO - CSR matrix is converted to CSC matrix. Time spent = 1.0403s.
# 2024-02-16 15:19:28,585 - pegasus.tools.diff_expr - INFO - MWU test and AUROC calculation are finished. Time spent = 1.5154s.
# 2024-02-16 15:19:28,738 - pegasus.tools.diff_expr - INFO - Sufficient statistics are collected. Time spent = 0.1531s.
# 2024-02-16 15:19:28,830 - pegasus.tools.diff_expr - INFO - Differential expression analysis is finished.
# 2024-02-16 15:19:28,830 - pegasus.tools.diff_expr - INFO - Function 'de_analysis' finished in 2.80s.

# %%
gene_list = ["AQP4", "GJA1", 
             "FLT1", "CLDN5", 
             "APBB1IP", "CX3CR1", 
             "MOBP", "MOG", 
             "OLIG1", "OLIG2", 
             "COLEC12", "EBF1", 
             "GAD1", "GAD2", 
             "SLC17A7", "SATB2"]

# %%
result = []
for group in [[x+"_CON", x+"_ALZ"] for x in ["Astro","Endo","Micro/PVM","Oligo","OPC","VLMC",
                             "Chandelier","Lamp5","Lamp5 Lhx6","Pax6","Pvalb","Sncg","Sst", "Sst Chodl","Vip",
                             "L2/3 IT","L4 IT","L5","L5/6 NP","L6 CT","L6 IT","L6 IT Car3","L6b"]]:
    result.append(group[0])
    result.append(group[1])

# %%
cluster_expr_CON
# Out:
#             Astro:log2Mean  Chandelier:log2Mean  Endo:log2Mean  \
# featurekey
# AQP4              4.901392             0.046852       0.000000
# GJA1              4.782771             0.045551       1.031118
# FLT1              0.004722             0.000000       7.030376
# CLDN5             0.016645             0.000000       8.646247
# APBB1IP           0.030013             0.125382       0.000000
# CX3CR1            0.009194             0.000000       0.000000
# MOBP              0.123943             0.000000       0.000000
# MOG               0.042542             0.044044       0.000000
# OLIG1             0.502642             0.132792       0.000000
# OLIG2             0.161787             0.000000       0.000000
# COLEC12           1.908805             0.122317       0.375887
# EBF1              0.047538             0.000000       4.181566
# GAD1              0.108763             2.527142       0.000000
# GAD2              0.023071             0.110977       0.000000
# SLC17A7           0.062823             0.564345       0.449771
# SATB2             0.228019             0.185271       0.895169
#
#             L2/3 IT:log2Mean  L4 IT:log2Mean  L5:log2Mean  L5/6 NP:log2Mean  \
# featurekey
# AQP4                0.350674        0.243149     0.217631          0.141144
# GJA1                0.008843        0.021564     0.006339          0.033017
# FLT1                0.037357        0.038361     0.045369          0.051485
# CLDN5               0.000000        0.003283     0.001378          0.000000
# APBB1IP             0.040336        0.031188     0.060143          0.050710
# CX3CR1              0.004856        0.000000     0.002397          0.000000
# MOBP                0.182952        0.178023     0.218961          0.331365
# MOG                 0.010221        0.019984     0.040075          0.035502
# OLIG1               0.015536        0.043823     0.059257          0.099480
# OLIG2               0.008029        0.024083     0.028789          0.075244
# COLEC12             0.093436        0.088721     0.060700          0.026110
# EBF1                0.011717        0.014365     0.028231          0.000000
# GAD1                0.021411        0.161594     0.170520          0.141875
# GAD2                0.022556        0.113619     0.153849          0.053178
# SLC17A7             4.643767        4.692810     5.206406          3.803930
# SATB2               4.419065        4.522898     3.960675          4.059783
#
#             L6 CT:log2Mean  L6 IT:log2Mean  L6 IT Car3:log2Mean  L6b:log2Mean  \
# featurekey
# AQP4              0.065836        0.301507             0.166601      0.171741
# GJA1              0.000000        0.046211             0.044500      0.091765
# FLT1              0.012744        0.046175             0.078367      0.031302
# CLDN5             0.012900        0.001959             0.000000      0.047453
# APBB1IP           0.042258        0.044592             0.043664      0.040057
# CX3CR1            0.000000        0.004905             0.000000      0.011220
# MOBP              0.066728        0.246647             0.208934      0.107586
# MOG               0.035307        0.035911             0.023008      0.047829
# OLIG1             0.051999        0.029494             0.032289      0.064535
# OLIG2             0.046965        0.033944             0.114725      0.000000
# COLEC12           0.014361        0.085590             0.100468      0.040640
# EBF1              0.020058        0.011837             0.015118      0.034350
# GAD1              0.154378        0.013963             0.092419      0.132211
# GAD2              0.091593        0.032503             0.068007      0.117448
# SLC17A7           4.493630        5.436661             5.546308      5.474207
# SATB2             2.981840        4.360998             5.639474      4.603142
#
#             Lamp5:log2Mean  Lamp5 Lhx6:log2Mean  Micro/PVM:log2Mean  \
# featurekey
# AQP4              0.014668             0.300111            0.063570
# GJA1              0.000000             0.000000            0.037376
# FLT1              0.042413             0.024708            0.110986
# CLDN5             0.012261             0.000000            0.000000
# APBB1IP           0.103941             0.142659            5.559642
# CX3CR1            0.012185             0.000000            2.112428
# MOBP              0.146245             0.160180            0.121995
# MOG               0.039656             0.103895            0.046810
# OLIG1             0.059258             0.022924            0.010811
# OLIG2             0.013432             0.017572            0.014022
# COLEC12           0.044681             0.131973            0.424184
# EBF1              0.018249             0.078562            0.099873
# GAD1              3.997259             3.572112            0.041209
# GAD2              5.294567             5.820876            0.016512
# SLC17A7           0.525193             0.678884            0.012851
# SATB2             0.107428             0.097917            0.041636
#
#             OPC:log2Mean  Oligo:log2Mean  Pax6:log2Mean  Pvalb:log2Mean  \
# featurekey
# AQP4            0.095796        0.004459       0.125741        0.034506
# GJA1            0.042230        0.010348       0.000000        0.025324
# FLT1            0.045219        0.011646       0.130139        0.174689
# CLDN5           0.000000        0.001041       0.000000        0.002866
# APBB1IP         0.049880        0.015313       0.000000        0.191609
# CX3CR1          0.012110        0.003436       0.000000        0.003490
# MOBP            0.047830        4.636469       0.069822        0.173183
# MOG             0.177169        2.696379       0.060436        0.059826
# OLIG1           4.407174        1.925437       0.154876        0.122227
# OLIG2           3.074277        0.812838       0.093384        0.027876
# COLEC12         0.055440        0.135069       0.132157        0.103721
# EBF1            0.039714        0.004985       0.072623        0.009784
# GAD1            1.767895        0.012635       4.326735        4.467743
# GAD2            0.053977        0.012508       3.357511        4.454978
# SLC17A7         0.101555        0.016316       1.019911        0.733094
# SATB2           0.075805        0.116257       0.236251        0.170371
#
#             Sncg:log2Mean  Sst:log2Mean  Sst Chodl:log2Mean  VLMC:log2Mean  \
# featurekey
# AQP4             0.050029      0.017507            0.000000       0.000000
# GJA1             0.000000      0.006327            0.000000       0.939097
# FLT1             0.017433      0.171266            0.000000       0.760242
# CLDN5            0.000000      0.000000            0.000000       0.477631
# APBB1IP          0.037439      0.028423            0.000000       0.126833
# CX3CR1           0.026747      0.000000            0.000000       0.151419
# MOBP             0.061185      0.113149            1.508757       0.000000
# MOG              0.065966      0.014552            1.541371       0.000000
# OLIG1            0.045917      0.042758            0.000000       0.000000
# OLIG2            0.000000      0.010310            0.613318       0.000000
# COLEC12          0.159429      0.018131            0.785401       5.124751
# EBF1             0.039961      0.000000            0.000000       2.994297
# GAD1             3.140292      3.372642            3.598524       0.000000
# GAD2             3.158471      2.924518            3.319838       0.125570
# SLC17A7          0.420420      0.588622            0.613318       0.000000
# SATB2            0.159862      0.126597            0.000000       0.097283
#
#             Vip:log2Mean
# featurekey
# AQP4            0.100720
# GJA1            0.025705
# FLT1            0.243872
# CLDN5           0.000000
# APBB1IP         0.048448
# CX3CR1          0.000000
# MOBP            0.047160
# MOG             0.007784
# OLIG1           0.033039
# OLIG2           0.000000
# COLEC12         0.104613
# EBF1            0.021490
# GAD1            3.683901
# GAD2            2.032569
# SLC17A7         0.420797
# SATB2           0.155457

# %%
cluster_expr_CON = pg.search_genes(data_CON, gene_list=gene_list, measure='log2Mean')
# cluster_expr_CON.columns = cluster_expr_CON.columns.str.replace(r":log2Mean", "")
# cluster_expr_CON = cluster_expr_CON[["Astro","Endo","Micro/PVM","Oligo","OPC","VLMC",
#                              "Chandelier","Lamp5","Lamp5 Lhx6","Pax6","Pvalb","Sncg","Sst", "Sst Chodl","Vip",
#                              "L2/3 IT","L4 IT","L5","L5/6 NP","L6 CT","L6 IT","L6 IT Car3","L6b"]]

# cluster_expr_DIS = pg.search_genes(data_DIS, gene_list=gene_list, measure='log2Mean')
# cluster_expr_DIS.columns = cluster_expr_DIS.columns.str.replace(r":log2Mean", "")
# cluster_expr_DIS = cluster_expr_DIS[["Astro","Endo","Micro/PVM","Oligo","OPC","VLMC",
#                              "Chandelier","Lamp5","Lamp5 Lhx6","Pax6","Pvalb","Sncg","Sst", "Sst Chodl","Vip",
#                              "L2/3 IT","L4 IT","L5","L5/6 NP","L6 CT","L6 IT","L6 IT Car3","L6b"]]

# cluster_expr = cluster_expr_CON.merge(cluster_expr_DIS, left_index=True, right_index=True)
# cluster_expr.columns = cluster_expr.columns.str.replace(r"_x", "_CON")
# cluster_expr.columns = cluster_expr.columns.str.replace(r"_y", "_ALZ")
# cluster_expr = cluster_expr[result]

# cluster_expr

# %%
cluster_expr.to_csv("subclass_markerExpr.csv", sep=",")

# %%
fig, ax = plt.subplots(figsize=(16, 46))

sns.heatmap(cluster_expr, cmap="crest", square=True, cbar=False)
fig.show()

# fig.savefig("plots-alz_inflam/marker_genes.pdf", bbox_inches='tight')

# %% [markdown]
# # Fig E: 3-dim c2c data structure

# %%
matrix = np.random.rand(22, 22)

# %%
fig, ax = plt.subplots(figsize=(22, 22))

sns.heatmap(matrix[:, 21].reshape((22, 1)), cmap="gray", square=True, cbar=False, 
            linewidths=3, linecolor='gray', xticklabels=False, yticklabels=False)
fig.show()

fig.savefig("/home/cl2553/project/C2C/plots/figA-alz_inflam-C2C_data_structure_col.pdf", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(22, 22))

sns.heatmap(matrix[0, :].reshape((1, 22)), cmap="gray", square=True, cbar=False, 
            linewidths=3, linecolor='gray', xticklabels=False, yticklabels=False)
fig.show()

fig.savefig("/home/cl2553/project/C2C/plots/figA-alz_inflam-C2C_data_structure_row.pdf", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(22, 22))

sns.heatmap(matrix, cmap="gray", square=True, cbar=False, 
            linewidths=3, linecolor='gray', xticklabels=False, yticklabels=False)
fig.show()

fig.savefig("/home/cl2553/project/C2C/plots/figA-alz_inflam-C2C_data_structure.pdf", bbox_inches='tight')
# fig.savefig("/home/cl2553/project/C2C/plots-alz_inflam/E-C2C_data_structure.pdf", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(27, 27))

sns.heatmap(np.ones((1, 27)), cmap="gray", square=True, cbar=False, 
            linewidths=3, linecolor='white', xticklabels=False, yticklabels=False)
fig.show()

fig.savefig("/home/cl2553/project/C2C/plots/figA-alz_inflam-C2C_data_structure_legend.pdf", bbox_inches='tight')
# fig.savefig("/home/cl2553/project/C2C/plots-alz_inflam/E-C2C_data_structure.pdf", bbox_inches='tight')
