# %%
library(CellChat)
library(anndata)
library(reticulate)
library(Matrix)
library(Seurat)
library(SeuratDisk)
library(NMF)
library(ggalluvial)
library(ComplexHeatmap)
library(patchwork)
library(graphics)
options(stringsAsFactors = FALSE)
library(glue)
args = commandArgs(trailingOnly=TRUE)
# Out:
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following object is masked from ‘package:circlize’:
#
#     degree
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Loading required package: ggplot2
#
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, were retired in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
#
# Attaching SeuratObject
#
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat
#
# Loading required package: registry
#
# Loading required package: rngtools
#
# Loading required package: cluster
#
# NMF - BioConductor layer [OK] | Shared memory capabilities [NO: bigmemory] | Cores 2/2
#
#   To enable shared memory capabilities, try: install.extras('
# NMF
# ')
#
#
# Attaching package: ‘NMF’
#
#
# The following objects are masked from ‘package:igraph’:
#
#     algorithm, compare

# %%
file <- '/extra/zhanglab0/CommonData/AMP-AD/AMP-AD_restricted/AMP-AD_ROSMAP_annotated.h5ad'
file
# Out:
# [1] "/extra/zhanglab0/CommonData/AMP-AD/AMP-AD_restricted/AMP-AD_ROSMAP_annotated.h5ad"

# %%
cellchat = read_h5ad(file)

# %%
cellchat
# Out:
# AnnData object with n_obs × n_vars = 63942 × 32270
#     obs: 'n_genes', 'n_counts', 'Channel', 'anno', 'subclass', 'azimuth', 'sampleID', 'individualID'
#     var: 'featureid', 'n_cells', 'percent_cells'
#     uns: 'PCs', '_attr2type', 'genome', 'leiden_resolution', 'modality', 'ncells', 'norm_count', 'pca', 'pca_features', 'stdzn_max_value', 'stdzn_mean', 'stdzn_std', 'uns_dict', 'var_dict'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_pca_regressed', 'X_pca_regressed_harmony', 'X_umap', 'pca_harmony_knn_distances', 'pca_harmony_knn_indices', 'pca_regressed_harmony_knn_distances', 'pca_regressed_harmony_knn_indices'
#     varm: 'de_res', 'means', 'partial_sum'
#     obsp: 'W_pca_harmony', 'W_pca_regressed_harmony'

# %%
unique(cellchat$obs$subclass)
# Out:
#  [1] L2/3 IT    L6 IT      L6b        L5 IT      L6 IT Car3 L4 IT
#  [7] L6 CT      Pvalb      Sst Chodl  Sst        Vip        Lamp5 Lhx6
# [13] Chandelier Astro      OPC        Micro/PVM  Lamp5      Pax6
# [19] Oligo      Sncg       VLMC       L5 ET      Endo       L5/6 NP
# 24 Levels: Astro Chandelier Endo L2/3 IT L4 IT L5 ET L5 IT L5/6 NP ... Vip

# %%
a <- cellchat$obs$subclass
a <- gsub('L2/3 IT', 'excit_l2_3',a)
a <- gsub('L4 IT', 'excit_l4',a)
a <- gsub('OPC', 'opc',a)
a <- gsub('Astro', 'astro',a)
a <- gsub('Endo', 'endomural',a)
a <- gsub('L5/6 NP', 'excit_l5_6',a)
a <- gsub('Micro/PVM', 'micro',a)
a <- gsub('Oligo', 'oligo',a)
a <- gsub('L5 ET', 'excit_l5',a)
a <- gsub('L5 IT', 'excit_l5',a)
a <- gsub('L5', 'excit_l5',a)
a <- gsub('L6 IT Car3', 'excite_l6',a)
a <- gsub('L6 IT', 'excite_l6',a)
a <- gsub('L6 CT', 'excite_l6',a)
a <- gsub('L6b', 'excite_l6',a)
a <- gsub('VLMC', 'endomural',a)
a <- gsub('Chandelier', 'inhib',a)
a <- gsub('Lamp5 Lhx6', 'inhib',a)
a <- gsub('Lamp5', 'inhib',a)
a <- gsub('Pax6', 'inhib',a)
a <- gsub('Pvalb', 'inhib',a)
a <- gsub('Sst Chodl', 'inhib',a)
a <- gsub('Sncg', 'inhib',a)
a <- gsub('Sst', 'inhib',a)
a <- gsub('Vip', 'inhib',a)
unique(a)
# Out:
#  [1] "excit_l2_3" "excite_l6"  "excit_l5"   "excit_l4"   "inhib"
#  [6] "astro"      "opc"        "micro"      "oligo"      "endomural"
# [11] "excit_l5_6"

# %%
unique(cellchat$obs$subclass)
# Out:
#  [1] L2/3 IT    L6 IT      L6b        L5 IT      L6 IT Car3 L4 IT
#  [7] L6 CT      Pvalb      Sst Chodl  Sst        Vip        Lamp5 Lhx6
# [13] Chandelier Astro      OPC        Micro/PVM  Lamp5      Pax6
# [19] Oligo      Sncg       VLMC       L5 ET      Endo       L5/6 NP
# 24 Levels: Astro Chandelier Endo L2/3 IT L4 IT L5 ET L5 IT L5/6 NP ... Vip

# %%
cellchat$obs$pooled <- a
cellchat$obs
# Out:
#                           n_genes n_counts Channel   anno       subclass
# D17-8753-TGCGCAGCATCGGGTC 10905   66946    D17-8753- L5 ET      L2/3 IT
# D17-8753-CTCGAAACATCGACGC 10375   59114    D17-8753- L5 ET      L6 IT
# D17-8753-TGCGCAGGTATCGCAT 10518   58903    D17-8753- L5 ET      L6 IT
# D17-8753-GTTACAGCACATTAGC 10268   49493    D17-8753- L5 ET      L2/3 IT
# D17-8753-TCCCGATCAATGTTGC  9969   48719    D17-8753- L5 IT-5    L6 IT
# D17-8753-ACTGAACAGTGGCACA  9739   46728    D17-8753- L6 IT-5    L6 IT
# D17-8753-GCAAACTAGCTGAAAT  9617   46443    D17-8753- L5 ET      L2/3 IT
# D17-8753-TGACTTTTCAGTCCCT  9349   44799    D17-8753- L5 ET      L2/3 IT
# D17-8753-TCGTACCCAGACAGGT  9256   42882    D17-8753- L5 ET      L2/3 IT
# D17-8753-ACACCAATCAGCTTAG  9551   42541    D17-8753- L6 IT-5    L6 IT
# D17-8753-TACAGTGTCATCGGAT  9360   42162    D17-8753- L6b        L6b
# D17-8753-AGGTCATCAATGGAGC  9271   40847    D17-8753- L5 IT-5    L5 IT
# D17-8753-GGAATAAAGCATCATC  9228   40472    D17-8753- L6 IT-5    L6 IT
# D17-8753-CAGCATAAGCGAAGGG  9201   39367    D17-8753- L2/3 IT-5  L6 IT
# D17-8753-GGACGTCCATCGGGTC  9403   39365    D17-8753- L6b        L6b
# D17-8753-CGAGAAGGTATCGCAT  8785   37259    D17-8753- L2/3 IT-5  L2/3 IT
# D17-8753-CGGTTAATCTTAGAGC  9043   36983    D17-8753- L2/3 IT-5  L2/3 IT
# D17-8753-CTCTACGGTTGAGTTC  8809   36944    D17-8753- L5 IT-5    L5 IT
# D17-8753-ACTTGTTAGGCCCTCA  8435   34379    D17-8753- L2/3 IT-5  L2/3 IT
# D17-8753-CCTAGCTTCATCGCTC  7981   34094    D17-8753- L6 IT Car3 L6 IT Car3
# D17-8753-TGACTTTTCAAGGCTT  8459   33959    D17-8753- L6 IT-5    L6 IT
# D17-8753-TGAGGGAAGGGTATCG  8709   33405    D17-8753- L6b        L6b
# D17-8753-CTACGTCTCTTCCTTC  7938   33133    D17-8753- L6 IT-5    L6 IT
# D17-8753-CGAACATGTAAGTAGT  8562   32261    D17-8753- L5 IT-5    L5 IT
# D17-8753-ACGTCAAAGACTAAGT  8482   32035    D17-8753- L2/3 IT-5  L2/3 IT
# D17-8753-TACGGTATCCGCGCAA  8308   31867    D17-8753- L2/3 IT-5  L2/3 IT
# D17-8753-GCTGGGTGTTGACGTT  8333   31135    D17-8753- L6 IT-5    L6 IT
# D17-8753-TTTCCTCCAATGCCAT  8202   31089    D17-8753- L2/3 IT-5  L2/3 IT
# D17-8753-ACACTGACAGGGTTAG  8387   30292    D17-8753- L6b        L6b
# D17-8753-TGGACGCGTTCGCTAA  7964   29838    D17-8753- L6 IT-5    L6 IT
# ⋮                         ⋮       ⋮        ⋮         ⋮          ⋮
# D17-8800-GAGGTGAGTAAGGGAA 1142    1813     D17-8800- Oligo-3    Oligo
# D17-8800-TGGGCGTTCTACCAGA 1080    1833     D17-8800- Oligo      Oligo
# D17-8800-CTACACCTCGGTGTTA 1316    1920     D17-8800- Vip        Vip
# D17-8800-AAATGCCGTGACGCCT 1034    1742     D17-8800- Oligo-3    Oligo
# D17-8800-CTTTGCGAGAAACCAT 1064    1750     D17-8800- Oligo      Oligo
# D17-8800-GACGCGTTCGTAGGAG 1159    1739     D17-8800- Oligo-2    Oligo
# D17-8800-GCTGGGTCAGACGCTC 1082    1665     D17-8800- Oligo-3    Oligo
# D17-8800-CCGTTCACAGCGAACA 1093    1664     D17-8800- Micro/PVM  Micro/PVM
# D17-8800-CACACTCTCTCTGAGA 1079    1702     D17-8800- VLMC       VLMC
# D17-8800-GTATCTTTCCTACAGA 1052    1635     D17-8800- Oligo-2    Oligo
# D17-8800-GCGGGTTCATCCCACT 1012    1633     D17-8800- Oligo-3    Oligo
# D17-8800-AAGGTTCCAACTGGCC 1022    1604     D17-8800- OPC-2      OPC
# D17-8800-AACTTTCCACCGTTGG 1000    1595     D17-8800- Oligo      Oligo
# D17-8800-GTCATTTGTAGCGTCC  989    1558     D17-8800- Oligo      Oligo
# D17-8800-TAGTGGTAGAATGTTG  930    1456     D17-8800- VLMC       Endo
# D17-8800-GACCAATTCCGCAGTG 1107    1621     D17-8800- L5 IT-2    L5 IT
# D17-8800-AGAGCTTTCTGGTTCC  849    1444     D17-8800- Oligo      Oligo
# D17-8800-AGTGAGGGTGCAACGA  958    1422     D17-8800- VLMC       VLMC
# D17-8800-AGTCTTTGTGTGCCTG  897    1399     D17-8800- Oligo      Oligo
# D17-8800-GCATGATCAAGTACCT  820    1245     D17-8800- Oligo-6    Oligo
# D17-8800-TGGCTGGAGTGAATTG  763    1169     D17-8800- Micro/PVM  Micro/PVM
# D17-8800-TTCTCCTCACCATGTA  758    1168     D17-8800- Sst        Pvalb
# D17-8800-TGGACGCAGACGCACA  754    1121     D17-8800- Oligo-4    Oligo
# D17-8800-CCTTACGGTGACAAAT  794     986     D17-8800- VLMC       L2/3 IT
# D17-8800-GTCCTCAGTCAGATAA  619     839     D17-8800- Oligo-6    Oligo
# D17-8800-GGACATTCATTCTCAT  566     760     D17-8800- Astro-2    Astro
# D17-8800-CGATGTAAGGGTTTCT  542     753     D17-8800- Micro/PVM  Micro/PVM
# D17-8800-CTGATCCCAATGGACG  532     742     D17-8800- Oligo-4    Oligo
# D17-8800-GCATACATCTTGCAAG  605     782     D17-8800- Sst        Sst
# D17-8800-GGATGTTAGCTAGTTC  541     731     D17-8800- Oligo-5    Oligo
#                           azimuth    sampleID individualID pooled
# D17-8753-TGCGCAGCATCGGGTC L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-CTCGAAACATCGACGC L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-TGCGCAGGTATCGCAT L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-GTTACAGCACATTAGC L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-TCCCGATCAATGTTGC L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-ACTGAACAGTGGCACA L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-GCAAACTAGCTGAAAT L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-TGACTTTTCAGTCCCT L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-TCGTACCCAGACAGGT L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-ACACCAATCAGCTTAG L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-TACAGTGTCATCGGAT L6b        D17-8753 ROS13        excite_l6
# D17-8753-AGGTCATCAATGGAGC L5 IT      D17-8753 ROS13        excit_l5
# D17-8753-GGAATAAAGCATCATC L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-CAGCATAAGCGAAGGG L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-GGACGTCCATCGGGTC L6b        D17-8753 ROS13        excite_l6
# D17-8753-CGAGAAGGTATCGCAT L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-CGGTTAATCTTAGAGC L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-CTCTACGGTTGAGTTC L5 IT      D17-8753 ROS13        excit_l5
# D17-8753-ACTTGTTAGGCCCTCA L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-CCTAGCTTCATCGCTC L6 IT Car3 D17-8753 ROS13        excite_l6
# D17-8753-TGACTTTTCAAGGCTT L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-TGAGGGAAGGGTATCG L6b        D17-8753 ROS13        excite_l6
# D17-8753-CTACGTCTCTTCCTTC L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-CGAACATGTAAGTAGT L5 IT      D17-8753 ROS13        excit_l5
# D17-8753-ACGTCAAAGACTAAGT L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-TACGGTATCCGCGCAA L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-GCTGGGTGTTGACGTT L6 IT      D17-8753 ROS13        excite_l6
# D17-8753-TTTCCTCCAATGCCAT L2/3 IT    D17-8753 ROS13        excit_l2_3
# D17-8753-ACACTGACAGGGTTAG L6b        D17-8753 ROS13        excite_l6
# D17-8753-TGGACGCGTTCGCTAA L6 IT      D17-8753 ROS13        excite_l6
# ⋮                         ⋮          ⋮        ⋮            ⋮
# D17-8800-GAGGTGAGTAAGGGAA Oligo      D17-8800 ROS40        oligo
# D17-8800-TGGGCGTTCTACCAGA Oligo      D17-8800 ROS40        oligo
# D17-8800-CTACACCTCGGTGTTA Vip        D17-8800 ROS40        inhib
# D17-8800-AAATGCCGTGACGCCT Oligo      D17-8800 ROS40        oligo
# D17-8800-CTTTGCGAGAAACCAT Oligo      D17-8800 ROS40        oligo
# D17-8800-GACGCGTTCGTAGGAG Oligo      D17-8800 ROS40        oligo
# D17-8800-GCTGGGTCAGACGCTC Oligo      D17-8800 ROS40        oligo
# D17-8800-CCGTTCACAGCGAACA Micro/PVM  D17-8800 ROS40        micro
# D17-8800-CACACTCTCTCTGAGA VLMC       D17-8800 ROS40        endomural
# D17-8800-GTATCTTTCCTACAGA Oligo      D17-8800 ROS40        oligo
# D17-8800-GCGGGTTCATCCCACT Oligo      D17-8800 ROS40        oligo
# D17-8800-AAGGTTCCAACTGGCC OPC        D17-8800 ROS40        opc
# D17-8800-AACTTTCCACCGTTGG Oligo      D17-8800 ROS40        oligo
# D17-8800-GTCATTTGTAGCGTCC Oligo      D17-8800 ROS40        oligo
# D17-8800-TAGTGGTAGAATGTTG Endo       D17-8800 ROS40        endomural
# D17-8800-GACCAATTCCGCAGTG L5 IT      D17-8800 ROS40        excit_l5
# D17-8800-AGAGCTTTCTGGTTCC Oligo      D17-8800 ROS40        oligo
# D17-8800-AGTGAGGGTGCAACGA VLMC       D17-8800 ROS40        endomural
# D17-8800-AGTCTTTGTGTGCCTG Oligo      D17-8800 ROS40        oligo
# D17-8800-GCATGATCAAGTACCT Oligo      D17-8800 ROS40        oligo
# D17-8800-TGGCTGGAGTGAATTG Micro/PVM  D17-8800 ROS40        micro
# D17-8800-TTCTCCTCACCATGTA Pvalb      D17-8800 ROS40        inhib
# D17-8800-TGGACGCAGACGCACA Oligo      D17-8800 ROS40        oligo
# D17-8800-CCTTACGGTGACAAAT L2/3 IT    D17-8800 ROS40        excit_l2_3
# D17-8800-GTCCTCAGTCAGATAA Oligo      D17-8800 ROS40        oligo
# D17-8800-GGACATTCATTCTCAT Astro      D17-8800 ROS40        astro
# D17-8800-CGATGTAAGGGTTTCT Micro/PVM  D17-8800 ROS40        micro
# D17-8800-CTGATCCCAATGGACG Oligo      D17-8800 ROS40        oligo
# D17-8800-GCATACATCTTGCAAG Sst        D17-8800 ROS40        inhib
# D17-8800-GGATGTTAGCTAGTTC Oligo      D17-8800 ROS40        oligo

# %%
cellchat$X
# Out:
#   [[ suppressing 32 column names ‘MIR1302-2HG’, ‘FAM138A’, ‘AL627309.1’ ... ]]
#
#   [[ suppressing 32 column names ‘MIR1302-2HG’, ‘FAM138A’, ‘AL627309.1’ ... ]]
#
#   [[ suppressing 32 column names ‘MIR1302-2HG’, ‘FAM138A’, ‘AL627309.1’ ... ]]

# %%
cellchat <- createCellChat(object = t(as(cellchat$X, 'CsparseMatrix')), meta = cellchat$obs, group.by = "pooled")
# Out:
# [1] "Create a CellChat object from a data matrix"
# Set cell identities for the new CellChat object
# The cell groups used for CellChat analysis are  astro endomural excit_l2_3 excit_l4 excit_l5 excit_l5_6 excite_l6 inhib micro oligo opc

# %%
cellchat
# Out:
# An object of class CellChat created from a single dataset
#  32270 genes.
#  63942 cells.
# CellChat analysis of single cell RNA-seq data!

# %%
# Parameter Tuning
# condition <- args[1]               # c("CON", "PTSD", "MDD")
# type <- args[2]                    # c("triMean", "truncatedMean", "thresholdedMean", "median")
# trim <- as.numeric(args[3])        # c(0.05, 0.10, 0.15, 0.20, 0.25)
condition <- c("CON", "PTSD", "MDD")
type <- "triMean"        #  c("triMean", "truncatedMean", "thresholdedMean", "median")
trim <- 0.1              #c(0.05, 0.10, 0.15, 0.20, 0.25)

#choose database
CellChatDB <- CellChatDB.human
CellChatDB.use <- subsetDB(CellChatDB, search = "Secreted Signaling") # use Secreted Signaling
#set the used database in the object
cellchat@DB <- CellChatDB.use
cellchat <- subsetData(cellchat)

# %%
#do parallel
library(future)
options(future.globals.maxSize = +Inf)
future::plan("multicore", workers = 16)

#analysis
cellchat <- identifyOverExpressedGenes(cellchat)
cellchat <- identifyOverExpressedInteractions(cellchat)
# Out:
# Attaching package: ‘future’
#
#
# The following object is masked from ‘package:NMF’:
#
#     run
#
#
# The following objects are masked from ‘package:igraph’:
#
#     %->%, %<-%

# %%
#create cellchat object
# cellchat <- createCellChat(object = data.input, meta = meta, group.by = "subclass_renamed")


######################################
## KEY LINE ##########################
cellchat <- computeCommunProb(cellchat, type = type, trim = trim)
######################################
# Out:
# triMean is used for calculating the average gene expression per cell group.
# [1] ">>> Run CellChat on sc/snRNA-seq data <<< [2023-10-15 10:29:39.978989]"
# [1] ">>> CellChat inference is done. Parameter values are stored in `object@options$parameter` <<< [2023-10-15 10:41:53.683226]"

# %%
#Filter out the cell-cell communication if there are only few number of cells in certain cell groups
cellchat <- filterCommunication(cellchat, min.cells = 10)

#Infer the cell-cell communication at a signaling pathway level
cellchat <- computeCommunProbPathway(cellchat)

# %%
#Calculate the aggregated cell-cell communication network
cellchat <- aggregateNet(cellchat)

#Identify global communication patterns to explore how multiple cell types and signaling pathways coordinate together
nPatterns = 3  #default, set to 3
cellchat <- identifyCommunicationPatterns(cellchat, pattern = "outgoing", k = nPatterns)
cellchat <- identifyCommunicationPatterns(cellchat, pattern = "incoming", k = nPatterns)
# Out:
# plot without title

# %%
# saveRDS(cellchat, 
#         file = glue("RNA_FINAL-{condition}-type_{type}-trim_{trim}_cellchat.rds"))

saveRDS(cellchat, 
        file = "cellchat_before_pooling.rds")

write.csv(cellchat@net$weight, "cellchat_before_pooling.csv")

print("\n\n\n")
print(paste0("Condition: ", condition))
print(paste0("Type: ", type))
print(paste0("Trim: ", trim))
print("DONE!")
# Out:
# [1] "\n\n\n"
# [1] "Condition: CON"  "Condition: PTSD" "Condition: MDD"
# [1] "Type: triMean"
# [1] "Trim: 0.1"
# [1] "DONE!"

# %% [markdown]
# # -------------

# %%
library(ComplexHeatmap)
library(circlize)
library(circlize)
library(colorspace)
library(ggplot2)

# %%
# inhibitory_celltypes <- c('Inh KCNG1', 'Inh LAMP5', 'Inh PVALB', 'Inh SST', 'Inh VIP')
# excitatory_celltypes <- c('Exc CUX2', 'Exc FEZF2', 'Exc OPRK1', 'Exc RORB')
# support_celltypes <- c('Astro', 'Endo', 'MG', 'Oligo', 'OPC')
cellchat = readRDS(
plot = my_merged_river(cellchat, "outgoing", 'AUD', inhibitory_celltypes, excitatory_celltypes, support_celltypes)
# Out:
# Error in eval(expr, envir, enclos): object 'cellchat' not found
# Traceback:
#
# 1. my_merged_river(cellchat, "outgoing", "AUD", inhibitory_celltypes,
#  .     excitatory_celltypes, support_celltypes)
# 2. methods::slot(object, "net_analysis")   # at line 20 of file <text>
