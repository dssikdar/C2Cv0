# %%
import numpy as np
import pandas as pd
import pegasus as pg
import json
import os
import pegasusio
from pegasusio import UnimodalData, MultimodalData
import matplotlib.pyplot as plt 
import scipy.sparse
import matplotlib.patches as mpatches
import itertools
import matplotlib.cm 
import scanpy as sc
from matplotlib.pyplot import rc_context
from matplotlib.gridspec import GridSpec

# %% [markdown]
# # 7 samples RNA

# %%
data = pg.read_input('/gpfs/gibbs/pi/girgenti/JZhang/CL/C2C/AD_Paper/Data/AMP-AD_ROSMAP_annotated.h5ad')
# Out:
# 2023-11-11 14:46:12,460 - pegasusio.readwrite - INFO - h5ad file '/gpfs/gibbs/pi/girgenti/JZhang/CL/C2C/AD_Paper/Data/AMP-AD_ROSMAP_annotated.h5ad' is loaded.
# 2023-11-11 14:46:12,461 - pegasusio.readwrite - INFO - Function 'read_input' finished in 12.86s.

# %%
data.obs['subclass'] = data.obs['subclass'].replace(['L5 ET', 'L5 IT'], 'L5')

# %%
data.obs['canon'] = None

# %%
data.obs['subclass'].cat.categories
# Out:
# Index(['Astro', 'Chandelier', 'Endo', 'L2/3 IT', 'L4 IT', 'L5', 'L5/6 NP',
#        'L6 CT', 'L6 IT', 'L6 IT Car3', 'L6b', 'Lamp5', 'Lamp5 Lhx6',
#        'Micro/PVM', 'OPC', 'Oligo', 'Pax6', 'Pvalb', 'Sncg', 'Sst',
#        'Sst Chodl', 'VLMC', 'Vip'],
#       dtype='object')

# %%
data.obs
# Out:
#                            n_genes  n_counts    Channel       anno   subclass  \
# barcodekey
# D17-8753-TGCGCAGCATCGGGTC    10905     66946  D17-8753-      L5 ET    L2/3 IT
# D17-8753-CTCGAAACATCGACGC    10375     59114  D17-8753-      L5 ET      L6 IT
# D17-8753-TGCGCAGGTATCGCAT    10518     58903  D17-8753-      L5 ET      L6 IT
# D17-8753-GTTACAGCACATTAGC    10268     49493  D17-8753-      L5 ET    L2/3 IT
# D17-8753-TCCCGATCAATGTTGC     9969     48719  D17-8753-    L5 IT-5      L6 IT
# ...                            ...       ...        ...        ...        ...
# D17-8800-GGACATTCATTCTCAT      566       760  D17-8800-    Astro-2      Astro
# D17-8800-CGATGTAAGGGTTTCT      542       753  D17-8800-  Micro/PVM  Micro/PVM
# D17-8800-CTGATCCCAATGGACG      532       742  D17-8800-    Oligo-4      Oligo
# D17-8800-GCATACATCTTGCAAG      605       782  D17-8800-        Sst        Sst
# D17-8800-GGATGTTAGCTAGTTC      541       731  D17-8800-    Oligo-5      Oligo
#
#                              azimuth  sampleID individualID canon
# barcodekey
# D17-8753-TGCGCAGCATCGGGTC    L2/3 IT  D17-8753        ROS13  None
# D17-8753-CTCGAAACATCGACGC      L6 IT  D17-8753        ROS13  None
# D17-8753-TGCGCAGGTATCGCAT      L6 IT  D17-8753        ROS13  None
# D17-8753-GTTACAGCACATTAGC    L2/3 IT  D17-8753        ROS13  None
# D17-8753-TCCCGATCAATGTTGC      L6 IT  D17-8753        ROS13  None
# ...                              ...       ...          ...   ...
# D17-8800-GGACATTCATTCTCAT      Astro  D17-8800        ROS40  None
# D17-8800-CGATGTAAGGGTTTCT  Micro/PVM  D17-8800        ROS40  None
# D17-8800-CTGATCCCAATGGACG      Oligo  D17-8800        ROS40  None
# D17-8800-GCATACATCTTGCAAG        Sst  D17-8800        ROS40  None
# D17-8800-GGATGTTAGCTAGTTC      Oligo  D17-8800        ROS40  None
#
# [63942 rows x 9 columns]

# %%
remove = ['Sst Chodl']
barcode_list = []
for ii,name in enumerate(data.obs_names):
    if data.obs.subclass[ii] in remove:
        barcode_list.append(False)
    else:
        barcode_list.append(True)
data_subset = data[barcode_list].copy()

# %%
data = MultimodalData(data_subset)

# %%
data.obs['subclass'].cat.remove_categories("Sst Chodl", inplace=True)
# Out:
# /tmp/ipykernel_3348213/4028950368.py:1: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   data.obs['subclass'].cat.remove_categories("Sst Chodl", inplace=True)

# %%
data.obs['subclass'].cat.categories
# Out:
# Index(['Astro', 'Chandelier', 'Endo', 'L2/3 IT', 'L4 IT', 'L5', 'L5/6 NP',
#        'L6 CT', 'L6 IT', 'L6 IT Car3', 'L6b', 'Lamp5', 'Lamp5 Lhx6',
#        'Micro/PVM', 'OPC', 'Oligo', 'Pax6', 'Pvalb', 'Sncg', 'Sst', 'VLMC',
#        'Vip'],
#       dtype='object')

# %%
ann = sc.AnnData(data.X)
ann.var_names = data.var_names
ann.obs_names = data.obs_names

# %%
ann.obs['Subclass'] = data.obs['subclass']

# %%
ann.obsm['umap'] = data.obsm['X_umap']

# %%
celltype_name = ["Astro","Endo","Micro/PVM","Oligo","OPC","VLMC",
                  "Chandelier","Lamp5","Lamp5 Lhx6","Pax6","Pvalb","Sncg","Sst","Vip",
                  "L2/3 IT","L4 IT","L5","L5/6 NP","L6 CT","L6 IT","L6 IT Car3","L6b"]

# %%
len(celltype_name)
# Out:
# 22

# %%
colors=['#FF7A9E', '#DBA300', '#59C200', '#00CEB7', '#00B7FF', '#F07DFF',
'#FF0000', '#FF1700', '#FF2F00', '#FF4600', '#FF5E00', '#FF7500', '#FF8D00', '#FFA500',
'#0000FF', '#0024DA', '#0048B6', '#006D91', '#00916D', '#00B648', '#00DA24', '#00FF00']

# %%
colors_matched=['#FF7A9E', '#FF0000', '#DBA300', '#0000FF', '#0024DA', '#0048B6', '#006D91', 
                '#00916D', '#00B648', '#00DA24', '#00FF00', '#FF1700', '#FF2F00', 
                '#59C200', '#00B7FF', '#00CEB7', '#FF4600', '#FF5E00', '#FF7500', '#FF8D00', '#F07DFF', 
                '#FFA500']

# %%
len(colors_matched)
# Out:
# 22

# %%
with rc_context({'figure.figsize': (5, 5)}):
    # sc.pl.umap(ann, color='Subclass', size=1, add_outline=True, legend_loc='right',palette=colors_matched, save='_7samples_rna.pdf',title=' ')
    sc.pl.umap(ann, color='Subclass', size=1, add_outline=False, legend_loc='on data',save='_7samples_rna-no_outline.pdf',title=' ')
# Out:
# WARNING: saving figure to file figures/umap_7samples_rna-no_outline.pdf
# /gpfs/gibbs/project/girgenti/cl2553/conda_envs/AUD-scRNA-pegasus/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
